# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\DM\sample_dataset.csv")

# %%
data = df[['Transaction Amount', 'Category']]

# %%
le = LabelEncoder()
data = df[['Transaction Amount', 'Category']].copy()

# %%
df['Cluster'] = data['Cluster']

# %%
print(df.head())
# Out:
#    Customer ID      Name    Surname Gender   Birthdate  Transaction Amount  \
# 0       752858      Sean  Rodriguez      F  2002-10-20               35.47
# 1        26381  Michelle     Phelps    NaN  1985-10-24             2552.72
# 2       305449     Jacob   Williams      M  1981-10-25              115.97
# 3       988259    Nathan     Snyder      M  1977-10-26               11.31
# 4       764762   Crystal      Knapp      F  1951-11-02               62.21
#
#          Date               Merchant Name     Category  Cluster
# 0  2023-04-03               Smith-Russell     Cosmetic        2
# 1  2023-07-17      Peck, Spence and Young       Travel        3
# 2  2023-09-20                  Steele Inc     Clothing        2
# 3  2023-01-11  Wilson, Wilson and Russell     Cosmetic        2
# 4  2023-06-13               Palmer-Hinton  Electronics        2

# %%
print("\nCustomers in each Cluster:")
print(df['Cluster'].value_counts())
# Out:
# Customers in each Cluster:
# Cluster
# 2    35576
# 0     9013
# 1     2771
# 3     2640
# Name: count, dtype: int64

# %%
plt.scatter(data['Transaction Amount'], data['Category'],
            c=data['Cluster'], cmap='viridis')
plt.xlabel("Transaction Amount")
plt.ylabel("Category")
plt.title("Customer Segmentation")
plt.show()
